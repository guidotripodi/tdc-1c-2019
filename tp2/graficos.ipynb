# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


sns.set()
rtts_entre_saltos = [0, 25.254058837890625, 8.395171165466309, 4.843648274739579, 3.7184794743855747, 204.93643283843994, 14.686799049377441, 21.08820279439294, 22.13317553202313, 27.713799476623535, 14.149975776672363, 56.371633211771666, 20.937053362528445, 5.644329388936342, 21.812287966410338, 10.791699091593443, 93.54477723439533, 26.267226537068666, 26.981361707051576, 1.3999621073405137]
cimbala_data = [0, 0.055370025728307966, 0.44567855256681166, 0.5279016324310978, 0.5539509771710326, 4.104546337538766, 0.30001793375848435, 0.15181583917413913, 0.12762315352750733, 0.0015766580484032353, 0.3124461974027615, 0.6650484768828172, 0.15531517514634594, 0.5093646641434023, 0.1350521817913342, 0.3901953378643373, 1.5256624962263228, 0.03191367440844228, 0.015380374491181955, 0.6076281304663256]

axis_x = np.arange(0,len(cimbala_data),1)

pto_de_corte = np.zeros(len(rtts_entre_saltos))
outliers_y = [204.93643283843994, 56.371633211771666, 93.54477723439533]
outliers_x = [5,11,16]
outliers_x_t = [5.5,11.5,16.5]

# for i in range(len(rtts_entre_saltos)):
#   outliers[i] = 70.58883279837809

fig, ax = plt.subplots(figsize=(10,4))
# sns.lineplot(x=axis_x,y=rtts_entre_saltos, marker='-o', color='r', ax=ax)
plt.plot(axis_x , cimbala_data, marker='.')

# for i in range(len(outliers_y)):
#   plt.text(outliers_x_t[i], outliers_y[i], s='Outlier')

# plt.scatter(outliers_x, outliers_y, marker='s', color = 'black')

ax.set_xticklabels(labels=axis_x)
ax.set_xticks(ticks= axis_x)
ax.legend(['Datos de Cimbala'], facecolor='w')
ax.set_xlabel('Numero de salto')
ax.set_ylabel('(Xi - X.mean)/S')
# plt.plot(axis_x, pto_de_corte, color='r')
plt.savefig('cimbala_data.png')
plt.show()
