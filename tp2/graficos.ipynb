# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


sns.set()
rtts_entre_saltos = [8.258914947509766, 8.663614590962737, 7.9720656077067105, 4.653485616048172, 203.303066889445, 4.892611503601074, 6.955560048421205, 3.245393435160281, 3.8926045099894395, 3.8901646931965956, 85.60095628102619, 6.368700663248717, 8.3554903666178, 3.0138254165649414, 19.683146476745605, 14.621567726135254, 126.22644901275635, 93.09412638346356, 43.50337187449139, 138.1993815633986, 43.1232]

axis_x = np.arange(0,len(rtts_entre_saltos),1)
outliers= np.zeros(len(rtts_entre_saltos))
for i in range(len(rtts_entre_saltos)):
  outliers[i] = 121.58883279837809

fig, ax = plt.subplots(figsize=(10,4))
# sns.lineplot(x=axis_x,y=rtts_entre_saltos, marker='-o', color='r', ax=ax)
plt.plot(axis_x,rtts_entre_saltos, marker='o')
# ax.set_xticklabels(labels=axis_x)
# ax.set_xticks(ticks= axis_x)
# ax.legend(['rtts_entre_saltos'], facecolor='w')
plt.plot(axis_x, outliers, color='r')
plt.show()
